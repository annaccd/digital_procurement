# %% [markdown]
# # Setup

# %%
# Import dependencies 
# python -m venv <name_of_virtual_environment>
# source  <name_of_virtual_environment>/bin/activate

import pandas as pd
import numpy as np
import os

# %%
# Build data frame with 'compras'

# set the directory containing the CSV files
directory = "/Users/annadeniz/Documents/py_scripts/digital_procurement/data/raw data/compras"

# get a list of all CSV files in the directory
csv_files = [file for file in os.listdir(directory) if file.endswith('.csv')]

# initialize an empty DataFrame to store the combined data
compras_df = pd.DataFrame()

# loop through the CSV files and append them to the combined DataFrame
for file in csv_files:
    file_path = os.path.join(directory, file)
    df = pd.read_csv(file_path, encoding='latin-1', delimiter=';')
    compras_df = pd.concat([compras_df, df], ignore_index=True)

# check the combined DataFrame
compras_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452617 entries, 0 to 452616
# Data columns (total 24 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Número do Contrato                  452617 non-null  object
#  1   Objeto                              452407 non-null  object
#  2   Fundamento Legal                    380758 non-null  object
#  3   Modalidade Compra                   452617 non-null  object
#  4   Situação Contrato                   452617 non-null  object
#  5   Código Órgão Superior               452617 non-null  int64
#  6   Nome Órgão Superior                 452617 non-null  object
#  7   Código Órgão                        452617 non-null  int64
#  8   Nome Órgão                          452617 non-null  object
#  9   Código UG                           452617 non-null  int64
#  10  Nome UG                             452617 non-null  object
#  11  Data Assinatura Contrato            452617 non-null  object
#  12  Data Publicação DOU                 452617 non-null  object
#  13  Data Início Vigência                452617 non-null  object
#  14  Data Fim Vigência                   448296 non-null  object
#  15  Código Contratado                   452617 non-null  object
#  16  Nome Contratado                     452614 non-null  object
#  17  Valor Inicial Compra                452617 non-null  object
#  18  Valor Final Compra                  452617 non-null  object
#  19  Número Licitação                    452617 non-null  int64
#  20  Código UG Licitação                 384138 non-null  float64
#  21  Nome UG Licitação                   384138 non-null  object
#  22  Código Modalidade Compra Licitação  384138 non-null  float64
#  23  Modalidade Compra Licitação         384138 non-null  object
# dtypes: float64(2), int64(4), object(18)
# memory usage: 82.9+ MB

# %% [markdown]
# # Data preprocessing

# %%
# Packages for data preprocessing

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
# Convert the text column to string type
compras_df['Objeto'] = compras_df['Objeto'].astype(str)

# %%
# Tokenization
compras_df['tokens'] = compras_df['Objeto'].apply(lambda x: word_tokenize(x, language='portuguese'))

# %%
# Lowercasing
compras_df['tokens'] = compras_df['tokens'].apply(lambda x: [word.lower() for word in x])

# %%
# Stopwords Removal
stop_words = set(stopwords.words('portuguese'))

extra_stop_words = ['objeto', 'contrato', 'fornecimento', 'contratação', ':', 'serviços', 'empresa', 'execução', 'prestação', 'aquisição', 'br', 'material', 'serviço', 'especializada', 'elaboração', '.', '/', ',','!','?']
stop_words.update(extra_stop_words)

compras_df['tokens'] = compras_df['tokens'].apply(lambda x: [word for word in x if word not in stop_words])

# %%
# Check new dataframe with tokens

compras_df.head()
# Out:
#   Número do Contrato                                             Objeto  \
# 0              22017  Objeto: Execução dos serviços de dedetização, ...
# 1              32017  Objeto: Contratação  de serviços de apoio oper...
# 2              12017  Objeto: CONTRATAÇÃO DE SERVIÇOS GRÁFICOS PARA ...
# 3            2332016  Objeto: SERVIÇOS DE LIMPEZA, CONSERVAÇÃO E HIG...
# 4              12017  Objeto: Contratação de empresa especializada n...
#
#                                     Fundamento Legal  \
# 0  Fundamento Legal: Lei 10520/2002, Lei 8666/93 ...
# 1                  Fundamento Legal: Lei nº 8.666/93
# 2             Fundamento Legal: 10520/2002 E 8666/93
# 3   LEI 8.666 DE 1993 E SUAS ALTERAÇÕES POSTERIORES.
# 4        Fundamento Legal: lei 8666/93, artg 24 - ii
#
#             Modalidade Compra Situação Contrato  Código Órgão Superior  \
# 0                      Pregão         Publicado                  40000
# 1  Pregão - Registro de Preço         Publicado                  26000
# 2                      Pregão     Não se aplica                  25000
# 3              Sem Informação           Fechado                  32000
# 4       Dispensa de Licitação         Publicado                  25000
#
#              Nome Órgão Superior  Código Órgão  \
# 0         Ministério do Trabalho         37202
# 1         Ministério da Educação         26403
# 2         Ministério da Economia         25000
# 3  Ministério de Minas e Energia         91081
# 4         Ministério da Economia         25000
#
#                                       Nome Órgão  Código UG  ...  \
# 0            Instituto Nacional do Seguro Social     511080  ...
# 1                  Instituto Federal do Amazonas     158446  ...
# 2  Ministério da Economia - Unidades com vínculo     170010  ...
# 3                            Empresas de Energia     910808  ...
# 4  Ministério da Economia - Unidades com vínculo     170258  ...
#
#   Código Contratado                                    Nome Contratado  \
# 0    15501741000123                        P. R. DE ALMEIDA & CIA LTDA
# 1    04465383000124    SUP SERVICOS DE CONSTRUCOES E MANUTENCAO EIRELI
# 2    17615848000128  TEIXEIRA IMPRESSAO DIGITAL E SOLUCOES GRAFICAS...
# 3    29212545000143                      NOVA RIO SERVICOS GERAIS LTDA
# 4    07346326000114                 REPROS SOLUCOES EM DOCUMENTOS LTDA
#
#   Valor Inicial Compra Valor Final Compra Número Licitação  \
# 0          119988,8600        119988,8600            22016
# 1            8240,6000          8240,6000            22015
# 2           33318,9400         33318,9400           112016
# 3          960348,0000        960348,0000               -2
# 4            7200,0000          7200,0000            12017
#
#   Código UG Licitação                             Nome UG Licitação  \
# 0            511080.0                     GERENCIA EXECUTIVA CUIABA
# 1            194008.0          COORDENACAO REGIONAL DO RIO NEGRO/AM
# 2            170010.0  SECRETARIA ESP. DA RECEITA FEDERAL DO BRASIL
# 3                 NaN                                           NaN
# 4            170258.0           INSPETORIA DA RFB NO RIO DE JANEIRO
#
#   Código Modalidade Compra Licitação Modalidade Compra Licitação  \
# 0                                5.0                      Pregão
# 1                              -99.0  Pregão - Registro de Preço
# 2                                5.0                      Pregão
# 3                                NaN                         NaN
# 4                                6.0       Dispensa de Licitação
#
#                                               tokens
# 0  [dedetização, englobando, desinsetização, desr...
# 1  [apoio, operacional, prestados, condições, est...
# 2  [gráficos, unidades, receita, federal, brasil,...
# 3  [limpeza, conservação, higienização, serem, re...
# 4  [impressao, equipamentos, manutenção, preventi...
#
# [5 rows x 25 columns]

# %%
# Vectorization
vectorizer = TfidfVectorizer(max_df=0.9, min_df=100)
X = vectorizer.fit_transform(compras_df['tokens'].apply(lambda x: ' '.join(x)))

# %% [markdown]
# # Topic modelling

# %%
# Perform topic modelling using Latent Dirichlet Allocation (LDA)
from sklearn.decomposition import LatentDirichletAllocation

lda = LatentDirichletAllocation(n_components=100, random_state=42)
lda.fit(X)
# Out:
# LatentDirichletAllocation(n_components=100, random_state=42)

# %%
# Get words and corresponding weights resulting from the topic model in a table

def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    
    return pd.DataFrame(topic_dict)

# %%
# Get name of each title: augment the number of words per topic and base it on the results 

no_top_words = 15

display_topics(lda, vectorizer.get_feature_names_out(), no_top_words)
# Out:
#       Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights  \
# 0              água          1244.5  reabilitação           842.3
# 1            esgoto          1193.6      próteses           526.8
# 2      laboratorial           942.6       órteses           470.5
# 3           univasf           789.9  profissional           429.8
# 4            coleta           602.2        medida           417.9
# 5               uso           551.8         favor           373.8
# 6        tratamento           461.9      paciente           343.3
# 7          contidas           452.7     segurados           340.0
# 8   características           445.6    prontuário           289.1
# 9            demais           363.4           sob           288.8
# 10             agua           346.1      programa           246.1
# 11          técnica           334.6       consumo           197.4
# 12          tratada           330.8       prótese           152.7
# 13        sanitário           316.6      alumínio           137.4
# 14      assistência           302.6         silva           124.2
#
#        Topic 2 words Topic 2 weights    Topic 3 words Topic 3 weights  \
# 0                mão          2508.4          receita           858.2
# 1               obra          2393.5           brasil           749.2
# 2          exclusiva          2037.4          federal           556.3
# 3          dedicação          1948.8        delegacia           510.9
# 4        continuados          1208.9         chaveiro           222.7
# 5   disponibilização          1136.3            dtcea           222.0
# 6             regime          1088.0    monitoramento           216.5
# 7        conservação           553.0             cftv           196.7
# 8            limpeza           548.7          sistema           170.0
# 9          prestados           520.9           alarme           168.8
# 10         materiais           509.7         circuito           162.8
# 11         condições           491.4           pessoa           158.9
# 12     estabelecidas           490.6  jurisdicionadas           154.2
# 13      equipamentos           489.4         jurídica           146.1
# 14                de           489.2          fechado           143.5
#
#    Topic 4 words Topic 4 weights  ... Topic 95 words Topic 95 weights  \
# 0     instalação           474.6  ...           bens            668.8
# 1       montagem           434.1  ...        imóveis            662.8
# 2     divisórias           318.3  ...       gráficos            530.6
# 3    desmontagem           209.0  ...     manutenção            346.4
# 4        goiânia           205.3  ...         móveis            339.2
# 5      persianas           203.2  ...          áreas            326.3
# 6            ifg           201.9  ...       externas            240.6
# 7    contrataçao           175.2  ...       internas            236.6
# 8     cabeamento           163.0  ...           ifce            215.8
# 9             go           162.2  ...       conjunto            199.8
# 10         goiás           132.7  ...         verdes            184.7
# 11    conectores           131.5  ...    conservação            182.7
# 12         hotel           129.1  ...           anti            141.9
# 13   estruturado           127.1  ...       reagente            130.5
# 14      trânsito           120.4  ...        clínico            122.0
#
#    Topic 96 words Topic 96 weights Topic 97 words Topic 97 weights  \
# 0              ml            370.5         tensão            397.3
# 1         lavagem            256.2           alta            296.9
# 2      patrocínio            240.4     subestação            237.9
# 3      realização            235.6          baixa            206.9
# 4            mesa            231.0          média            196.2
# 5          roupas            228.5          ufrgs            185.4
# 6          evento            213.7          corpo            162.7
# 7        cultural            195.3        nobreak            120.1
# 8           bndes            187.7    subestações            119.5
# 9         oficina            160.0        entrada            114.9
# 10   apresentação            156.8        energia            111.4
# 11           cama            141.9       caminhão            106.0
# 12          banho            131.2       elétrica            105.4
# 13          roupa            125.8           auto            102.6
# 14      injetável            125.0           rede             90.4
#
#    Topic 98 words Topic 98 weights Topic 99 words Topic 99 weights
# 0           meses           1217.0     assinatura            408.0
# 1              12           1065.3       descrito            277.6
# 2         período            749.0       primeira            275.2
# 3            doze            635.9           ifpr            258.9
# 4              60            230.9       cláusula            232.7
# 5           prazo            222.6          anual            187.5
# 6         periodo            182.6        digital            156.6
# 7          anatel            154.8        revista            150.9
# 8            2019            140.9       conforme            150.3
# 9        sessenta            138.8        líquido            142.4
# 10             nd            138.0     biblioteca            128.0
# 11           cmdo            136.6      renovação            114.6
# 12        podendo            127.9        atender            113.2
# 13         339039            127.8     nitrogênio            111.2
# 14         limite            127.1          termo             99.2
#
# [15 rows x 200 columns]

# %%
# Create df with topics per item

W = lda.transform(X)

df_w = pd.DataFrame(W)

df_w.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.001736  0.001736  0.001736  0.001736  0.001736  0.001736  0.001736
# 1  0.002761  0.002761  0.002761  0.002761  0.002761  0.002761  0.002761
# 2  0.001803  0.001803  0.001803  0.291804  0.001803  0.001803  0.001803
# 3  0.002439  0.002439  0.002439  0.002439  0.002439  0.002439  0.002439
# 4  0.002396  0.002396  0.002396  0.002396  0.002396  0.002396  0.002396
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.001736  0.138207  0.001736  ...  0.001736  0.001736  0.001736  0.001736
# 1  0.002761  0.002761  0.002761  ...  0.002761  0.002761  0.002761  0.002761
# 2  0.071687  0.001803  0.001803  ...  0.001803  0.001803  0.001803  0.001803
# 3  0.002439  0.002439  0.002439  ...  0.002439  0.002439  0.002439  0.002439
# 4  0.564944  0.002396  0.002396  ...  0.002396  0.002396  0.002396  0.002396
#
#          94        95        96        97        98        99
# 0  0.118934  0.001736  0.001736  0.001736  0.001736  0.001736
# 1  0.002761  0.002761  0.002761  0.002761  0.002761  0.002761
# 2  0.001803  0.001803  0.001803  0.001803  0.001803  0.001803
# 3  0.002439  0.002439  0.002439  0.002439  0.002439  0.002439
# 4  0.002396  0.002396  0.002396  0.002396  0.002396  0.002396
#
# [5 rows x 100 columns]

# %%
# Merge compras_df with df with topics per item

compras_topics_df = pd.concat([compras_df,df_w], axis=1)

compras_topics_df.head()
# Out:
#   Número do Contrato                                             Objeto  \
# 0              22017  Objeto: Execução dos serviços de dedetização, ...
# 1              32017  Objeto: Contratação  de serviços de apoio oper...
# 2              12017  Objeto: CONTRATAÇÃO DE SERVIÇOS GRÁFICOS PARA ...
# 3            2332016  Objeto: SERVIÇOS DE LIMPEZA, CONSERVAÇÃO E HIG...
# 4              12017  Objeto: Contratação de empresa especializada n...
#
#                                     Fundamento Legal  \
# 0  Fundamento Legal: Lei 10520/2002, Lei 8666/93 ...
# 1                  Fundamento Legal: Lei nº 8.666/93
# 2             Fundamento Legal: 10520/2002 E 8666/93
# 3   LEI 8.666 DE 1993 E SUAS ALTERAÇÕES POSTERIORES.
# 4        Fundamento Legal: lei 8666/93, artg 24 - ii
#
#             Modalidade Compra Situação Contrato  Código Órgão Superior  \
# 0                      Pregão         Publicado                  40000
# 1  Pregão - Registro de Preço         Publicado                  26000
# 2                      Pregão     Não se aplica                  25000
# 3              Sem Informação           Fechado                  32000
# 4       Dispensa de Licitação         Publicado                  25000
#
#              Nome Órgão Superior  Código Órgão  \
# 0         Ministério do Trabalho         37202
# 1         Ministério da Educação         26403
# 2         Ministério da Economia         25000
# 3  Ministério de Minas e Energia         91081
# 4         Ministério da Economia         25000
#
#                                       Nome Órgão  Código UG  ...        90  \
# 0            Instituto Nacional do Seguro Social     511080  ...  0.001736
# 1                  Instituto Federal do Amazonas     158446  ...  0.002761
# 2  Ministério da Economia - Unidades com vínculo     170010  ...  0.001803
# 3                            Empresas de Energia     910808  ...  0.002439
# 4  Ministério da Economia - Unidades com vínculo     170258  ...  0.002396
#
#          91        92        93        94        95        96        97  \
# 0  0.001736  0.001736  0.001736  0.118934  0.001736  0.001736  0.001736
# 1  0.002761  0.002761  0.002761  0.002761  0.002761  0.002761  0.002761
# 2  0.001803  0.001803  0.001803  0.001803  0.001803  0.001803  0.001803
# 3  0.002439  0.002439  0.002439  0.002439  0.002439  0.002439  0.002439
# 4  0.002396  0.002396  0.002396  0.002396  0.002396  0.002396  0.002396
#
#          98        99
# 0  0.001736  0.001736
# 1  0.002761  0.002761
# 2  0.001803  0.001803
# 3  0.002439  0.002439
# 4  0.002396  0.002396
#
# [5 rows x 125 columns]

# %% [markdown]
# # Set initial dataset for labelling

# %%
# Analyse topics with potential for digital technology

topics_df = pd.DataFrame(display_topics(lda, vectorizer.get_feature_names_out(), no_top_words))

topics_df.to_csv('topics_df.csv', index=False)

# %%
# Topics with potential for gitial technology

digital_topics = topics_df.loc[:,['Topic 36 words', 'Topic 64 words', 'Topic 75 words', 'Topic 92 words']]

digital_topics
# Out:
#    Topic 36 words Topic 64 words   Topic 75 words Topic 92 words
# 0         solução       digitais        processos       software
# 1        garantia          dados       secretaria        suporte
# 2         suporte  processamento         direitos       licenças
# 3      instalação         pacote              tic        técnico
# 4            rede   certificados       tecnologia    atualização
# 5            site           meio       informação        licença
# 6    configuração       correios         técnicos     manutenção
# 7              on        emissão       ministério            uso
# 8   armazenamento       produtos  desenvolvimento      softwares
# 9           meses        digital           gestão        sistema
# 10          dados   certificação     documentação        solução
# 11        técnico    informações   especializados     subscrição
# 12   equipamentos            icp          humanos      microsoft
# 13             36     comerciais      implantação    treinamento
# 14       expansão         acesso         nacional         versão

# %%
# Create subset of the dataset with most relevant data for labelling

subset_1 = compras_topics_df[compras_topics_df[92] > 0.75] # 732 entries

subset_2 = compras_topics_df[compras_topics_df[92] < 0.75]

subset_2 = subset_2.sample(frac=0.0008, random_state=42) # 362 entries

subset_1.info()
subset_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 732 entries, 697 to 451686
# Columns: 125 entries, Número do Contrato to 99
# dtypes: float64(102), int64(4), object(19)
# memory usage: 720.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 362 entries, 371484 to 148642
# Columns: 125 entries, Número do Contrato to 99
# dtypes: float64(102), int64(4), object(19)
# memory usage: 356.3+ KB

# %%
# Join datasets

initial_df = pd.concat([subset_1,subset_2])

initial_df = initial_df.sample(frac=1)

initial_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1094 entries, 354253 to 118611
# Columns: 125 entries, Número do Contrato to 99
# dtypes: float64(102), int64(4), object(19)
# memory usage: 1.1+ MB

# %% [markdown]
# # Label data

# %%
# Export dataset for labeling

initial_df.to_csv('initial_df.csv')

# %%
# Launch Open Source Data Labeling Platform - https://labelstud.io/

# %%
# Import labeled data 

# Defined categories: 'Digital Technology' and 'Other'

seed_df = pd.read_json('labeled_data.json')

seed_df.head()
# Out:
#    Unnamed: 0  Número do Contrato  \
# 0       25564             1122018
# 1      307257              352021
# 2       86384               22015
# 3      133339              102018
# 4      444569              262013
#
#                                               Objeto  \
# 0  Objeto: PRESTAÇÃO DE SERVIÇO DE PACOTE DE ACES...
# 1  Objeto: O OBJETO DO PRESENTE INSTRUMENTO É A C...
# 2  Objeto: PRESTAÇÃO DE SERVIÇOS DE LOCAÇÃO DE CE...
# 3  Objeto: Contrato de prestação de serviços de s...
# 4  Objeto: Aquisição de licenças perpétuas de sol...
#
#                                     Fundamento Legal  \
# 0                      Fundamento Legal: LEI 8666/93
# 1
# 2                     Fundamento Legal: LEI 8.666/93
# 3  Fundamento Legal: LEI 8.666/93 E DEMAIS CORREL...
# 4  Fundamento Legal: Leis 8666/93, 10520/02 e Dec...
#
#               Modalidade Compra Situação Contrato  Código Órgão Superior  \
# 0  Inexigibilidade de Licitação     Não se aplica                  26000
# 1  Inexigibilidade de Licitação     Não se aplica                  36000
# 2    Pregão - Registro de Preço     Não se aplica                  25000
# 3                        Pregão         Publicado                  22000
# 4                        Pregão         Publicado                  25000
#
#                              Nome Órgão Superior  Código Órgão  \
# 0                         Ministério da Educação         26247
# 1                            Ministério da Saúde         36201
# 2                         Ministério da Economia         25000
# 3  Ministério da Agricultura, Pecuária e Abastec         22202
# 4                         Ministério da Economia         25000
#
#                                       Nome Órgão  ...        97        98  \
# 0            Universidade Federal de Santa Maria  ...  0.003679  0.003679
# 1                          Fundação Oswaldo Cruz  ...  0.002161  0.002161
# 2  Ministério da Economia - Unidades com vínculo  ...  0.002157  0.002157
# 3    Empresa Brasileira de Pesquisa Agropecuária  ...  0.002524  0.002524
# 4  Ministério da Economia - Unidades com vínculo  ...  0.001630  0.001630
#
#          99    id           sentiment annotator annotation_id  \
# 0  0.003679  1362               Other         1            48
# 1  0.002161  1363               Other         1            49
# 2  0.002157  1364               Other         1            50
# 3  0.002524  1365  Digital Technology         1            51
# 4  0.001630  1366  Digital Technology         1            52
#
#                         created_at                       updated_at lead_time
# 0 2023-03-22 17:25:52.126185+00:00 2023-03-22 17:25:52.126224+00:00    39.786
# 1 2023-03-22 17:26:16.896686+00:00 2023-03-22 17:26:16.896715+00:00    24.531
# 2 2023-03-22 17:26:24.304412+00:00 2023-03-22 17:26:24.304443+00:00     7.204
# 3 2023-03-22 17:28:00.333478+00:00 2023-03-22 17:28:00.333501+00:00    95.832
# 4 2023-03-22 17:28:12.296439+00:00 2023-03-22 17:28:12.296489+00:00    11.782
#
# [5 rows x 133 columns]

# %% [markdown]
# # Model

# %%
# Import packages

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
# Set features and target variables

X_seed = seed_df['tokens']
y = seed_df['sentiment']

# %%
# Split the data into training and test sets

X_train, X_test, y_train, y_test = train_test_split(X_seed, y, test_size=0.25, random_state=42)

# %%
# Vectorize the text using TF-IDF vectorizer

X_train_vec = vectorizer.transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
# Train a logistic regression model

classifier = LogisticRegression()
classifier.fit(X_train_vec, y_train)
# Out:
# LogisticRegression()

# %%
# Predict the labels for the test set

y_pred = classifier.predict(X_test_vec)

# %%
# Evaluate the accuracy of the model

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.96

# %%
# Print the classification report

report = classification_report(y_test, y_pred, zero_division=0)
print(report)
# Out:
#                     precision    recall  f1-score   support
#
# Digital Technology       0.97      0.95      0.96       148
#              Other       0.94      0.97      0.95       126
#
#           accuracy                           0.96       274
#          macro avg       0.96      0.96      0.96       274
#       weighted avg       0.96      0.96      0.96       274

# %%
# Save trained model

import pickle

with open('trained_classifier.pkl', 'wb') as f:
    pickle.dump(classifier, f)

# %% [markdown]
# # Predicting labels for the whole dataset

# %%
# Vectorize the text using the same vectorizer as before

X_unlabeled_vec = X

# %%
# Predict the labels for the unlabeled data

y_pred = classifier.predict(X_unlabeled_vec)

# %%
# Store the predicted labels in original dataframe

compras_df['category'] = y_pred

# %%
# Check final distribution of categories in the dataset

categories = compras_df.groupby('category')

categories['Objeto'].count()
# Out:
# category
# Digital Technology      9740
# Other                 442877
# Name: Objeto, dtype: int64

# %%
# Check results 

compras_df_dig = compras_df[compras_df['category'] == 'Digital Technology']

compras_df_dig['Objeto']
# Out:
# 27        Objeto: PRESTAÇÃO DE SERVIÇOS DE LICENÇA DE US...
# 46        Objeto: Renovação de licenças de software de s...
# 101       Objeto: Contratação de Solução de Sistema de p...
# 159       OBJETO: Prestação de subscrição suse e da pres...
# 246       Objeto: PRESTAÇÃO DE SERVIÇOS DE APOIO TÉCNICO...
#                                 ...
# 452531    Objeto: CONTRATAÇÃO DE SERVIÇOS DE TECNOLOGIA ...
# 452540    Objeto: O PRESENTE CONTRATO TEM POR OBJETO A C...
# 452591    Objeto: CONTRATAÇÃO DE SOLUÇÃO DE SOFTWARE PAR...
# 452601    Objeto: AQUISIÇÃO DE SOLUÇÃO DE COMUNICAÇÃO DE...
# 452608    Objeto: AQUISIÇÃO DE LICENÇAS DE SOFTWARE DO T...
# Name: Objeto, Length: 9740, dtype: object

# %% [markdown]
# # Descriptive analysis with new labels

# %%
compras_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452617 entries, 0 to 452616
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Número do Contrato                  452617 non-null  object
#  1   Objeto                              452617 non-null  object
#  2   Fundamento Legal                    380758 non-null  object
#  3   Modalidade Compra                   452617 non-null  object
#  4   Situação Contrato                   452617 non-null  object
#  5   Código Órgão Superior               452617 non-null  int64
#  6   Nome Órgão Superior                 452617 non-null  object
#  7   Código Órgão                        452617 non-null  int64
#  8   Nome Órgão                          452617 non-null  object
#  9   Código UG                           452617 non-null  int64
#  10  Nome UG                             452617 non-null  object
#  11  Data Assinatura Contrato            452617 non-null  object
#  12  Data Publicação DOU                 452617 non-null  object
#  13  Data Início Vigência                452617 non-null  object
#  14  Data Fim Vigência                   448296 non-null  object
#  15  Código Contratado                   452617 non-null  object
#  16  Nome Contratado                     452614 non-null  object
#  17  Valor Inicial Compra                452617 non-null  object
#  18  Valor Final Compra                  452617 non-null  object
#  19  Número Licitação                    452617 non-null  int64
#  20  Código UG Licitação                 384138 non-null  float64
#  21  Nome UG Licitação                   384138 non-null  object
#  22  Código Modalidade Compra Licitação  384138 non-null  float64
#  23  Modalidade Compra Licitação         384138 non-null  object
#  24  tokens                              452617 non-null  object
#  25  category                            452617 non-null  object
# dtypes: float64(2), int64(4), object(20)
# memory usage: 89.8+ MB

# %%
# Distribution of contracts per category per year

compras_df['Data Publicação DOU'] = pd.to_datetime(compras_df['Data Publicação DOU'], format='%d/%m/%Y')

compras_df['Ano Contrato'] = compras_df['Data Publicação DOU'].dt.year

category_year = pd.DataFrame(compras_df.groupby('Ano Contrato')['category'].value_counts().unstack().fillna(0).astype(int))

category_year
# Out:
# category      Digital Technology  Other
# Ano Contrato
# 2013                         962  45236
# 2014                        1008  50447
# 2015                         786  41637
# 2016                         919  43120
# 2017                        1093  44088
# 2018                        1243  48570
# 2019                         988  49482
# 2020                        1209  52512
# 2021                         863  37264
# 2022                         669  30521

# %%
# Distribution of contracts per category per department

category_department = pd.DataFrame(compras_df.groupby('Nome Órgão Superior')['category'].value_counts().unstack().fillna(0).astype(int))

category_department
# Out:
# category                                       Digital Technology   Other
# Nome Órgão Superior
# Advocacia-Geral da União                                       47    2226
# Banco Central do Brasil - Orçamento Fiscal e                  235    6056
# Controladoria-Geral da União                                   70     452
                     'Ministério das Mulheres, Igualdade Racial, da': 'Ministério da Cidadania'}

compras_df['Ministério'] = compras_df['Nome Órgão Superior'].replace(departments_group)

# %%
# Distribution of contracts of digital technology per department per year

digi_department_year = compras_df[compras_df['category'] == 'Digital Technology']

digi_department_year = pd.DataFrame(digi_department_year.groupby('Ministério')['Ano Contrato'].value_counts().unstack().fillna(0).astype(int))

digi_department_year
# Out:
# Ano Contrato                                        2013  2014  2015  2016  \
# Ministério
# Banco Central do Brasil                               32    37    19    20
# Ministério da Agricultura, Pecuária e Abastecim...    42    35    36    33
# Ministério da Cidadania                                7    19     6    11
# Ministério da Ciência, Tecnologia e Inovações         38    44    28    36
# Ministério da Defesa                                  93    98    96   121
# Ministério da Economia                               116   142   120   144
# Ministério da Educação                               210   224   151   222
# Ministério da Infraestrutura                          43    40    43    35
# Ministério da Justiça e Segurança Pública             50    64    47    45
# Ministério da Saúde                                   40    51    49    60
# Ministério das Comunicações                           14    12    13    10
# Ministério das Relações Exteriores                     7     3     5     4
# Ministério de Minas e Energia                        168   128    99   104
# Ministério do Desenvolvimento Regional                40    35    17    27
# Ministério do Meio Ambiente                            2     8     6     7
# Ministério do Trabalho                                 8    13     7     5
# Ministério do Turismo                                 19    27    23    19
# Presidência da República                              33    28    21    16
#
# Ano Contrato                                        2017  2018  2019  2020  \
# Ministério
# Banco Central do Brasil                               37    21    12    25
# Ministério da Agricultura, Pecuária e Abastecim...    25    47    21    24
# Ministério da Cidadania                                9    23     9    12
# Ministério da Ciência, Tecnologia e Inovações         41    51    41    37
# Ministério da Defesa                                 118   130   125   195
# Ministério da Economia                               142   122   106   146
# Ministério da Educação                               243   347   303   377
# Ministério da Infraestrutura                          71    51    35    51
# Ministério da Justiça e Segurança Pública             66    90    53    77
# Ministério da Saúde                                   91    91    69    85
# Ministério das Comunicações                           28    16    10    11
# Ministério das Relações Exteriores                     8     6     1    11
# Ministério de Minas e Energia                         94    89    85    56
# Ministério do Desenvolvimento Regional                38    39    27    24
# Ministério do Meio Ambiente                           13    35    22    19
# Ministério do Trabalho                                15    15    10    18
# Ministério do Turismo                                 30    38    35    20
# Presidência da República                              24    32    24    21
#
# Ano Contrato                                        2021  2022
# Ministério
# Banco Central do Brasil                               22    10
# Ministério da Agricultura, Pecuária e Abastecim...    16    11
# Ministério da Cidadania                               11     1
# Ministério da Ciência, Tecnologia e Inovações         41    19
# Ministério da Defesa                                 125   100
# Ministério da Economia                                49    43
# Ministério da Educação                               307   287
# Ministério da Infraestrutura                          43    20
# Ministério da Justiça e Segurança Pública             49    24
# Ministério da Saúde                                   65    54
# Ministério das Comunicações                           20    11
# Ministério das Relações Exteriores                     4     4
# Ministério de Minas e Energia                         53    37
# Ministério do Desenvolvimento Regional                16     8
# Ministério do Meio Ambiente                           10     8
# Ministério do Trabalho                                 7     4
# Ministério do Turismo                                 13    15
# Presidência da República                              12    13

# %%
# Distribution of percentage of contracts of digital technology per department per year

perc_digi_department_year = compras_df.groupby(['Ministério', 'Ano Contrato'])['category'].apply(lambda x: (x == 'Digital Technology').sum() / len(x) * 100)

perc_digi_department_year = pd.DataFrame(perc_digi_department_year).reset_index()

perc_digi_department_year = perc_digi_department_year.pivot(index='Ministério', columns='Ano Contrato', values='category').fillna(0)

perc_digi_department_year = perc_digi_department_year.round(2)

perc_digi_department_year
# Out:
# Ano Contrato                                        2013  2014  2015  2016  \
# Ministério
# Banco Central do Brasil                             3.04  3.62  2.58  2.32
# Ministério da Agricultura, Pecuária e Abastecim...  2.25  1.92  2.53  2.71
# Ministério da Cidadania                             4.67  7.22  4.44  7.86
# Ministério da Ciência, Tecnologia e Inovações       5.69  5.39  4.95  6.46
# Ministério da Defesa                                1.53  1.23  1.47  1.48
# Ministério da Economia                              3.34  3.19  3.46  4.21
# Ministério da Educação                              1.64  1.62  1.21  1.76
# Ministério da Infraestrutura                        3.52  3.02  3.43  3.20
# Ministério da Justiça e Segurança Pública           2.32  2.82  2.32  2.09
# Ministério da Saúde                                 1.43  2.09  1.99  2.28
# Ministério das Comunicações                         3.32  2.75  2.99  2.50
# Ministério das Relações Exteriores                  8.33  3.49  6.33  5.19
# Ministério de Minas e Energia                       3.79  2.99  2.18  2.87
# Ministério do Desenvolvimento Regional              2.13  2.08  1.58  3.11
# Ministério do Meio Ambiente                         0.41  1.34  0.96  1.68
# Ministério do Trabalho                              0.17  0.20  0.20  0.10
# Ministério do Turismo                               2.95  3.60  4.25  3.27
# Presidência da República                            3.01  2.96  3.45  3.77
#
# Ano Contrato                                        2017   2018  2019  2020  \
# Ministério
# Banco Central do Brasil                             4.99   3.35  2.75  6.93
# Ministério da Agricultura, Pecuária e Abastecim...  2.07   3.74  1.82  1.90
# Ministério da Cidadania                             5.81   4.61  1.47  3.35
# Ministério da Ciência, Tecnologia e Inovações       6.74   7.35  6.07  5.27
# Ministério da Defesa                                1.34   1.27  0.99  1.28
# Ministério da Economia                              4.34   3.83  3.32  4.51
# Ministério da Educação                              1.92   2.33  1.94  2.19
# Ministério da Infraestrutura                        5.78   3.43  2.63  3.31
# Ministério da Justiça e Segurança Pública           2.86   2.77  1.48  2.23
# Ministério da Saúde                                 3.02   2.95  1.65  1.56
# Ministério das Comunicações                         6.75   4.11  2.73  2.72
# Ministério das Relações Exteriores                  9.20   5.00  1.01  9.40
# Ministério de Minas e Energia                       2.62   3.08  5.37  7.90
# Ministério do Desenvolvimento Regional              3.45   4.69  3.59  3.08
# Ministério do Meio Ambiente                         2.33   5.09  4.31  4.42
# Ministério do Trabalho                              0.34   0.31  0.36  1.17
# Ministério do Turismo                               4.99   6.56  5.25  2.98
# Presidência da República                            5.05  10.22  8.33  8.54
#
# Ano Contrato                                         2021   2022
# Ministério
# Banco Central do Brasil                              7.94   5.65
# Ministério da Agricultura, Pecuária e Abastecim...   2.40   1.99
# Ministério da Cidadania                              3.63   0.70
# Ministério da Ciência, Tecnologia e Inovações        7.59   5.19
# Ministério da Defesa                                 0.96   1.00
# Ministério da Economia                               3.03   2.68
# Ministério da Educação                               2.60   2.71
# Ministério da Infraestrutura                         4.30   2.79
# Ministério da Justiça e Segurança Pública            2.01   1.44
# Ministério da Saúde                                  1.85   1.75
# Ministério das Comunicações                          5.18   4.37
# Ministério das Relações Exteriores                   5.33   5.71
# Ministério de Minas e Energia                       10.71  12.76
# Ministério do Desenvolvimento Regional               4.94   2.46
# Ministério do Meio Ambiente                          1.79   2.31
# Ministério do Trabalho                               1.12   0.72
# Ministério do Turismo                                3.92   5.03
# Presidência da República                            12.00  12.87

# %% [markdown]
# # Performance metric across departments

# %%
# Distribution of percentage of contracts of digital technology per department

perc_digi_department = compras_df.groupby(['Ministério'])['category'].apply(lambda x: (x == 'Digital Technology').sum() / len(x) * 100)

perc_digi_department = pd.DataFrame(perc_digi_department)

perc_digi_department = perc_digi_department.sort_values(by='category', ascending=False)

perc_digi_department = perc_digi_department.round(2)

perc_digi_department = perc_digi_department.rename(columns={'category': 'Digital Technology %'})

perc_digi_department
# Out:
#                                                     Digital Technology %
# Ministério
# Ministério da Ciência, Tecnologia e Inovações                       6.07
# Ministério das Relações Exteriores                                  5.93
# Presidência da República                                            4.87
# Ministério do Turismo                                               4.22
# Ministério da Cidadania                                             3.92
# Banco Central do Brasil                                             3.74
# Ministério das Comunicações                                         3.71
# Ministério da Economia                                              3.65
# Ministério da Infraestrutura                                        3.54
# Ministério de Minas e Energia                                       3.45
# Ministério do Desenvolvimento Regional                              2.82
# Ministério do Meio Ambiente                                         2.49
# Ministério da Agricultura, Pecuária e Abastecim...                  2.33
# Ministério da Justiça e Segurança Pública                           2.23
# Ministério da Saúde                                                 2.00
# Ministério da Educação                                              1.99
# Ministério da Defesa                                                1.22
# Ministério do Trabalho                                              0.30

# %%
# create a new dataframe grouped by department
#digi_dept = compras_df[compras_df['category'] == 'Digital Technology'].groupby('Código Órgão Superior')

# calculate the percentage of digital technology contracts per department
#digi_pct = digi_dept['Valor Final Compra'].count() / compras_df.groupby('Código Órgão Superior')['Valor Final Compra'].count() * 100

# calculate the average spending on digital technology contracts per department
#digi_avg_spending = digi_dept['Valor Final Compra'].sum() / digi_dept['Valor Final Compra'].count()

# create a new dataframe combining the two metrics
#digi_metrics = pd.DataFrame({'digital_technology_pct': digi_pct, 'digital_technology_avg_spending': digi_avg_spending})

# merge the new dataframe with the original one to add department names
#digi_metrics = pd.merge(digi_metrics, compras_df[['Código Órgão Superior', 'Nome Órgão Superior']].drop_duplicates(), on='Código Órgão Superior')

# sort the dataframe by descending percentage of digital technology contracts
#digi_metrics = digi_metrics.sort_values('digital_technology_pct', ascending=False)

# reset the index and rename columns for readability
#digi_metrics = digi_metrics.reset_index(drop=True)
#digi_metrics.columns = ['Department Code', 'Digital Technology Contract Percentage', 'Digital Technology Average Spending', 'Department Name']

# display the resulting dataframe
#digi_metrics

# %%
compras_df['Valor Contrato'] = compras_df['Valor Final Compra'].str.replace(',', '.').astype(float)

# Calculate Digital Technology Contract Percentage per department
digital_percentage = (compras_df['category'] == 'Digital Technology').groupby(compras_df['Ministério']).mean() * 100

# Calculate Digital Technology Average Spending per department
digital_spending = compras_df[compras_df['category'] == 'Digital Technology'].groupby('Ministério')['Valor Contrato'].mean()

# Calculate the weighted average of the two metrics
w1 = 0.7
w2 = 0.3
digital_indicator = (digital_percentage * w1) + (digital_spending * w2)

# Sort the indicator values in descending order
digital_indicator = digital_indicator.sort_values(ascending=False)

digital_indicator = digital_indicator.round(2)

# Print the results
digital_indicator
# Out:
# Ministério
# Ministério do Trabalho                                 7825658.21
# Ministério da Economia                                 1667697.02
# Ministério da Cidadania                                1664577.58
# Ministério da Infraestrutura                           1623582.20
# Ministério da Saúde                                    1244665.58
# Ministério das Relações Exteriores                     1176311.39
# Ministério da Justiça e Segurança Pública              1098216.23
# Banco Central do Brasil                                 723118.03
# Ministério da Agricultura, Pecuária e Abastecimento     698530.98
# Ministério da Educação                                  678316.61
# Ministério do Meio Ambiente                             671984.48
# Ministério das Comunicações                             595068.26
# Ministério da Defesa                                    558969.59
# Ministério do Desenvolvimento Regional                  505727.14
# Presidência da República                                458576.03
# Ministério de Minas e Energia                           429366.21
# Ministério da Ciência, Tecnologia e Inovações           411971.24
# Ministério do Turismo                                   297731.37
# dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

# create a scaler object
scaler = MinMaxScaler()

# fit and transform the indicator values
indicator_values = digital_indicator.values.reshape(-1, 1)
normalized_values = scaler.fit_transform(indicator_values)

# add the normalized values to the dataframe
normalized_values
# Out:
# array([[1.        ],
#        [0.18198445],
#        [0.18157007],
#        [0.1761243 ],
#        [0.12578951],
#        [0.11670943],
#        [0.10633537],
#        [0.05650781],
#        [0.0532417 ],
#        [0.05055645],
#        [0.0497153 ],
#        [0.03949785],
#        [0.03470255],
#        [0.02762989],
#        [0.0213664 ],
#        [0.0174862 ],
#        [0.01517548],
#        [0.        ]])

# %%
# calculate the performance indicator
digi_spending_per_dept = compras_df[compras_df['category'] == 'Digital Technology'].groupby('Ministério')['Valor Contrato'].agg(['sum', 'count'])
digi_spending_per_dept['Digital Technology Average Spending'] = digi_spending_per_dept['sum'] / digi_spending_per_dept['count']
digi_spending_per_dept.drop(['sum', 'count'], axis=1, inplace=True)
digi_contract_pct_per_dept = compras_df.groupby('Código Órgão Superior')['category'].apply(lambda x: (x == 'Digital Technology').mean() * 100)
performance_indicator = pd.concat([digi_contract_pct_per_dept, digi_spending_per_dept], axis=1)
performance_indicator = performance_indicator.fillna(0)

# normalize the performance indicator
performance_indicator_norm = (performance_indicator - performance_indicator.min()) / (performance_indicator.max() - performance_indicator.min())

# create the desired dataframe
performance_df = pd.DataFrame({'Ministério': performance_indicator_norm.index, 'Performance Indicator': performance_indicator_norm.values.flatten()})
performance_df.set_index('Ministério', inplace=True)
